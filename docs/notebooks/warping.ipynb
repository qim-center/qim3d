# %%
import qim3d

# %% [markdown]
# ### Volume operations and warping notebook
#
# This notebook displays qim3d's warping and volumetric operations that can be applied to modify volumes using the `operations` submodule. This submodule contains the functions:
#
# * `pad()`
# * `pad_to()`
# * `trim()`
# * `shear3d()`
# * `curve_warp()`
# * `strech()`
# * `center_twist()`
#
# Additionally, the functions `rotate`and `shift` from `scipy.ndimage` can be used to rotate or translate a volume. We refer to their documentation for use of these functions.
#
# First we will generate a volume:

# %%
vol = qim3d.generate.volume(base_shape = (300, 50, 50),
                                    final_shape = (300, 50, 50),
                                    noise_scale = 0.002,
                                    volume_shape = "cylinder"
                                    )

# %%
qim3d.viz.volumetric(vol, grid_visible=True)
# Out:
# Output()

# %% [markdown]
# The operations in this submodule will modify the volume coordinates using `scipy.ndimage.map_coordinates` which may place the new coordinates outside of the original volume boundaries. Therefore we apply padding before the operations such that we don't lose information. We will trim this padding afterwards, such that we don't have an unnecessarily large volume.
#
# We can pad the image in two ways:

# %% [markdown]
# First, we can pad the volume pixelwise or with the relative size of the original volume using `qim3d.operations.pad()`.
#
# In this case, the volume has size (300, 50, 50). We will apply warping primarily in the x- and y axes, so let's pad the volume in these directions.
#
# We can pad the volume pixelwise with:

# %%
# Pad the image with 20 pixels on each side of the x- and y axis
vol_padded = qim3d.operations.pad(vol, x_axis=20, y_axis=20)
print(vol_padded.shape)
# Out:
# (300, 90, 90)

# %% [markdown]
# Alternatively we can apply the padding as some percentage of the size of the original volume:

# %%
# Determine the amount of padding (20% on each axis)
x_pad = vol.shape[2] * 0.10
y_pad = vol.shape[1] * 0.10

# We use 10% since the padding will be added to both sides

# Apply the padding
vol_padded =qim3d.operations.pad(vol, x_axis=x_pad, y_axis=y_pad)
print(vol_padded.shape)
# Out:
# (300, 60, 60)

# %% [markdown]
# If we already know what size we wish to pad the volume to, we can instead use `qim3d.operations.pad_to()`:

# %%
# Pad the volume to shape (300, 100, 100)
vol_padded = qim3d.operations.pad_to(vol, (300, 100, 100))
print(vol_padded.shape)
# Out:
# (300, 100, 100)

# %% [markdown]
# Now that we have a volume with increased size, let's apply some operations.
#
# First we have `shear3d()`. This function applies a shear in a three-dimensional space. Since we are working in three dimensions, we must both define what direction to shear and along what axis.
#
# To apply a shear in the x-direction along the z-axis with a pixel displacement of 40, we can do as shown below. If the shear should be in a different direction, we can reverse the sign of the pixel displacement or change the direction with a different variable (e.g. y_shift_z to shear in y direction along the z-axis).

# %%
# Apply shear
vol_sheared = qim3d.operations.shear3d(vol_padded, x_shift_z=40)

# Visualize result
qim3d.viz.volumetric(vol_sheared, grid_visible=True)
# Out:
# 0.0
# Output()

# %% [markdown]
# We also have the `curve_warp()` function. This function applies a sine-curve warping along the z-axis. Here we have an amplitude parameter, x_amp, that determines the size of the curve, a period parameter, x_periods that determines the amount of curves and the offset parameter x_offset, that allows us to start the curve at a different height. All these have corresponding arguments for the y-axis.
#
# An example is:

# %%
# Apply a curve warp along the x-axis
vol_warped = qim3d.operations.curve_warp(vol_padded, x_amp=20, x_periods=2, x_offset=30)

# Visualize the result
qim3d.viz.volumetric(vol_warped, grid_visible=True)
# Out:
# Output()

# %% [markdown]
# The `stretch()` function can stretch or shrink a volume along one of the primary axes. This function applies the stretch in the total volume space, making padding unnecessary.

# %%
# Apply the stretch with 40 pixels along the x-axis
vol_stretched = qim3d.operations.stretch(vol, x_stretch=40)

# Visualize the result
qim3d.viz.volumetric(vol_stretched, grid_visible=True)
# Out:
# Output()

# %% [markdown]
# Lastly the `center_twist()` function applies a twist along an axis, rotating the volume from one end to another. Since we are only using one cylinder in this case, the operation won't be very clear. Therefore we will start by generating a collection of volumes:

# %%
vol_col, label_col = qim3d.generate.volume_collection(num_volumes = 20,
                                            collection_shape = (300, 150, 150),
                                            min_shape = (280, 10, 10),
                                            max_shape = (290, 15, 15),
                                            min_volume_noise = 0.008,
                                            max_volume_noise = 0.009,
                                            max_rotation_degrees = 5,
                                            min_threshold = 0.7,
                                            max_threshold = 0.9,
                                            min_gamma = 0.10,
                                            max_gamma = 0.11,
                                            volume_shape = "cylinder"
                                            )
# Out:
# Objects placed:   0%|          | 0/20 [00:00<?, ?it/s]

# %% [markdown]
# We then pad the volume to ensure we don't lose information followed by a 180 degree twist along the z-axis

# %%
# Pad volume to (300, 200, 200)
vol_col_pad = qim3d.operations.pad_to(vol_col, (300, 200, 200))

# Apply a 180 degree twist along z-axis
vol_col_twist = qim3d.operations.center_twist(vol_col_pad, rotation_angle=180, axis='z')

# Visualize the result
qim3d.viz.volumetric(vol_col_twist, grid_visible=True)
# Out:
# Output()

# %% [markdown]
# After visualizing, we notice that there is a lot of blank space in the volume after the operations due to excessive padding. We can remove this, to achieve faster runtimes using the `trim()` function, that removes empty slices in all directions:

# %%
# Trim the volume
print(f"Original shape after padding: {vol_col_twist.shape}")
vol_col_trim = qim3d.operations.trim(vol_col_twist)
print(f"Shape after trimming: {vol_col_trim.shape}")

qim3d.viz.volumetric(vol_col_trim, grid_visible=True)
# Out:
# Original shape after padding: (300, 200, 200)
# Shape after trimming: (299, 181, 165)
# Output()

# %% [markdown]
# Using these operations together, we can permute the volume in interesting ways - for example using the generate module to create fiber-like structures. In the case of the volume collections, that additionally have labels, we can apply the same transformations to the labels, such that we can use them for further analysis.
#
# A pipeline could look like:

# %%
def pipeline(vol_col, label_col):
    
    # Pad the volumes with 30%
    vol_col = qim3d.operations.pad(vol_col, x_axis=vol_col.shape[2]*0.25, y_axis=vol_col.shape[1]*0.25, z_axis=0)
    label_col = qim3d.operations.pad(label_col, x_axis=label_col.shape[2]*0.25, y_axis=label_col.shape[1]*0.25, z_axis=0)

    # Apply curve warp
    vol_col = qim3d.operations.curve_warp(vol_col, x_amp=-20, x_periods=1.1, order=0)
    label_col = qim3d.operations.curve_warp(label_col, x_amp=-20, x_periods=1.1, order=0)

    # Apply center twist
    vol_col = qim3d.operations.center_twist(vol_col, rotation_angle=270, order=0)
    label_col = qim3d.operations.center_twist(label_col, rotation_angle=270, order=0)

    # Apply shear
    vol_col = qim3d.operations.shear3d(vol_col, y_shift_z=5, x_shift_z=-50, order=0)
    label_col = qim3d.operations.shear3d(label_col, y_shift_z=5, x_shift_z=-50, order=0)

    # Trim the volumes
    vol_col = qim3d.operations.trim(vol_col)
    label_col = qim3d.operations.trim(label_col)

    # Return the volumes
    return vol_col, label_col

vol_col_fiber, label_col_fiber = pipeline(vol_col, label_col)

# %%
# Visualize the results
qim3d.viz.volumetric(vol_col_fiber, grid_visible=True)
# Out:
# Output()

# %% [markdown]
# Notice in this piece of code, we have changed the default value of the `order` argument. This argument determines the order of the spline interpolation, which defines the degree of the B-spline used for interpolation. More details can be found in the [map_coordinates](https://docs.scipy.org/doc/scipy/reference/generated/scipy.ndimage.map_coordinates.html) documentation. In general, using a higher order results in a smoother output, which can enhance visual appearance. However, higher-order interpolation approximates values, which can distort discrete labels (e.g., segmentation masks).
#
# Therefore, when applying the same transformation to labeled data as to a continuous volume, we recommend setting order=0 to preserve discrete values and avoid interpolation artifacts.

# %% [markdown]
# We can visualize the labels using `qim3d.viz.slicer`, using the 'segmentation' color map:

# %%
qim3d.viz.slicer(label_col_fiber, color_map='segmentation')
# Out:
# interactive(children=(IntSlider(value=149, description='Slice', max=298), Output()), layout=Layout(align_items…
